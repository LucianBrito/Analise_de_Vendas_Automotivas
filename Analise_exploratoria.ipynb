# %%
# Importar bibliotecas necessárias
import os
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns   
import numpy as np

# %%
df = pd.read_excel(r"C:\Users\Lenovo\OneDrive\Desktop\Codigos Python\Base de dados\dados.xlsx")

# %%
df.head
# Out:
# <bound method NDFrame.head of      DATA_VENDA        MODELO  KM-LITRO  CILINDROS  PESO(KG)  \
# 0     10/1/2020    LABORGUINI       3.0         12      1200
# 1     10/1/2020    LABORGUINI       3.0         12      1200
# 2     10/1/2020    LABORGUINI       3.0         12      1200
# 3     10/1/2020       FERRARI       3.0         12      1400
# 4     10/1/2020  ASTON MARTIN       3.5         10      1600
# ..          ...           ...       ...        ...       ...
# 981  10/12/2021     HONDA FIT      12.0          4      1700
# 982  10/12/2021         PALIO      11.0          4      1700
# 983  10/12/2021           UNO      13.5          4      1700
# 984  10/12/2021          MOBI      14.0          4      1700
# 985  10/12/2021        PASSAT       8.0          6      1800
#
#      VELOCIDADE_MAXIMA(KM/H)  CAVALOS TRANSMISSAO     VALOR  CATEGORIA
# 0                        360      700  AUTOMATICO  50000000  IMPORTADO
# 1                        360      700  AUTOMATICO  50000000  IMPORTADO
# 2                        360      700  AUTOMATICO    900000  IMPORTADO
# 3                        360      640  AUTOMATICO    900000  IMPORTADO
# 4                        360      620  AUTOMATICO    900000  IMPORTADO
# ..                       ...      ...         ...       ...        ...
# 981                      200      116  AUTOMATICO    120000   NACIONAL
# 982                      200      118      MANUAL     60000   NACIONAL
# 983                      200      118      MANUAL     48000   NACIONAL
# 984                      200      118      MANUAL     42000   NACIONAL
# 985                      200      118      MANUAL    200000  IMPORTADO
#
# [986 rows x 10 columns]>

# %%
#Comando utilizado para verificar a quantidade de linhas e colunas do arquivo
df.shape
# Out:
# (986, 10)

# %%
#Comando utilizado para verificar as linhas finais do DataFrame
df.tail()
# Out:
#      DATA_VENDA     MODELO  KM-LITRO  CILINDROS  PESO(KG)  \
# 981  10/12/2021  HONDA FIT      12.0          4      1700
# 982  10/12/2021      PALIO      11.0          4      1700
# 983  10/12/2021        UNO      13.5          4      1700
# 984  10/12/2021       MOBI      14.0          4      1700
# 985  10/12/2021     PASSAT       8.0          6      1800
#
#      VELOCIDADE_MAXIMA(KM/H)  CAVALOS TRANSMISSAO   VALOR  CATEGORIA
# 981                      200      116  AUTOMATICO  120000   NACIONAL
# 982                      200      118      MANUAL   60000   NACIONAL
# 983                      200      118      MANUAL   48000   NACIONAL
# 984                      200      118      MANUAL   42000   NACIONAL
# 985                      200      118      MANUAL  200000  IMPORTADO

# %%
#Comando utilizado para verificar informações sobre os dados(Tipo de variáveis, Variáveis, Quantidade de registros, etc)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   DATA_VENDA               986 non-null    object
#  1   MODELO                   986 non-null    object
#  2   KM-LITRO                 984 non-null    float64
#  3   CILINDROS                986 non-null    int64
#  4   PESO(KG)                 986 non-null    int64
#  5   VELOCIDADE_MAXIMA(KM/H)  986 non-null    int64
#  6   CAVALOS                  986 non-null    int64
#  7   TRANSMISSAO              986 non-null    object
#  8   VALOR                    986 non-null    object
#  9   CATEGORIA                986 non-null    object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 77.2+ KB

# %%
# Comando utilizado para avaliar se alguma variável possui valor nulo ou chamado de valores missing ou NAN (Not Available)
df.isnull().sum()
# Out:
# DATA_VENDA                 0
# MODELO                     0
# KM-LITRO                   2
# CILINDROS                  0
# PESO(KG)                   0
# VELOCIDADE_MAXIMA(KM/H)    0
# CAVALOS                    0
# TRANSMISSAO                0
# VALOR                      0
# CATEGORIA                  0
# dtype: int64

# %%
#Comando utilizado para fazer uma analise rápida com medidas estatisticas(Média, Mediana, Desvio Padrão, etc)
df.describe()
# Out:
#          KM-LITRO   CILINDROS     PESO(KG)  VELOCIDADE_MAXIMA(KM/H)  \
# count  984.000000  986.000000   986.000000               986.000000
# mean     8.209553    6.115619  1959.432049               255.334686
# std      3.718411    2.764683   459.769620                71.111120
# min      3.000000    3.000000  1200.000000               200.000000
# 25%      4.500000    4.000000  1700.000000               200.000000
# 50%      8.000000    4.000000  1700.000000               200.000000
# 75%     11.000000    8.000000  2300.000000               360.000000
# max     14.000000   12.000000  3000.000000               360.000000
#
#            CAVALOS
# count   986.000000
# mean    262.622718
# std     209.544669
# min     116.000000
# 25%     118.000000
# 50%     118.000000
# 75%     340.000000
# max    1800.000000

# %%
# Total de valores únicos de cada variável
valores_unicos = []
for i in df_dados.columns[0:14].tolist():
    print(i, ':', len(df[i].astype(str).value_counts()))
    valores_unicos.append(len(df[i].astype(str).value_counts()))
# Out:
# DATA_VENDA : 24
# MODELO : 22
# KM-LITRO : 15
# CILINDROS : 6
# PESO(KG) : 14
# VELOCIDADE_MAXIMA(KM/H) : 5
# CAVALOS : 13
# TRANSMISSAO : 2
# VALOR : 20
# CATEGORIA : 2

# %%
# Aqui podemos observar a quantidade de registros por tipo de transmissao
df.groupby(['TRANSMISSAO']).size()
# Out:
# TRANSMISSAO
# AUTOMATICO    536
# MANUAL        450
# dtype: int64

# %%
# Podemos observar as informações acimas todas de uma vez através de gráficos

plt.rcParams["figure.figsize"] = [14.00, 8.00]
plt.rcParams["figure.autolayout"] = True
f, axes = plt.subplots(2, 2)

sns.countplot(data = df, x="CILINDROS", ax=axes[0][0])
sns.countplot(data = df, x="CAVALOS", ax=axes[0][1])
sns.countplot(data = df, x="TRANSMISSAO", ax=axes[1][0])
sns.countplot(data = df, x="CATEGORIA", ax=axes[1][1])

plt.show()
